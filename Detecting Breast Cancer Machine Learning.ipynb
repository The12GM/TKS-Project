# %% [markdown]
# # Detecting Breast Caner using ML

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
bc_df = pd.read_csv(r"C:\Users\gokul\Downloads\data.csv")
bc_df.dropna(axis = 1, inplace = True)
bc_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
bc_df["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
sns.countplot(data = bc_df, x = "diagnosis")
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
Labelencoder = LabelEncoder()
bc_df.iloc[:,1] = Labelencoder.fit_transform(bc_df.iloc[:,1].values)
bc_df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
bc_df["diagnosis"].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
sns.pairplot(bc_df.iloc[:,1:9],hue = "diagnosis")

# %%
bc_df.corr()
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
fig = plt.figure (figsize = (25,20))

ax1 = fig.add_subplot()
ax1 = sns.heatmap(bc_df.iloc[:,1:].corr(), annot = True)

plt.show()

# %%
x = bc_df.iloc[:, 2:31].values
y = bc_df["diagnosis"].values

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.20, random_state= 100)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train,y_train)
log_reg.score(x_train,y_train)
# Out:
# 0.9934065934065934

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
# Out:
# 1.0

# %%
s = SVC()

s.fit(x_train,y_train)
s.score(x_train,y_train)
# Out:
# 0.989010989010989

# %%
cm = confusion_matrix(y_test, log_reg.predict(x_test))
df = pd.DataFrame(cm, index = ["cancer","healthy"], columns = ["predicted cancer","predicted healthy"])
df
# Out:
#          predicted cancer  predicted healthy
# cancer                 65                  0
# healthy                 3                 46

# %%
cm = confusion_matrix(y_test, dt.predict(x_test))
df = pd.DataFrame(cm, index = ["cancer","healthy"], columns = ["predicted cancer","predicted healthy"])
df
# Out:
#          predicted cancer  predicted healthy
# cancer                 63                  2
# healthy                 4                 45

# %%
cm = confusion_matrix(y_test, rf.predict(x_test))
df = pd.DataFrame(cm, index = ["cancer","healthy"], columns = ["predicted cancer","predicted healthy"])
df
# Out:
#          predicted cancer  predicted healthy
# cancer                 64                  1
# healthy                 3                 46

# %%
cm = confusion_matrix(y_test, s.predict(x_test))
df = pd.DataFrame(cm, index = ["cancer","healthy"], columns = ["predicted cancer","predicted healthy"])
df
# Out:
#          predicted cancer  predicted healthy
# cancer                 64                  1
# healthy                 3                 46
